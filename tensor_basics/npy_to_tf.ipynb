# %%
import numpy as np
import tensorflow as tf

# %%
np_arr=np.array([1,2,4])
print(np_arr)
# Out:
# [1 2 4]

# %%
convert_tensor=tf.convert_to_tensor(np_arr)
print(convert_tensor)
# Out:
# tf.Tensor([1 2 4], shape=(3,), dtype=int64)
