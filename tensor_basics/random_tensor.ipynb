# %%
import tensorflow as tf

# %%
random=tf.random.normal([3,2],mean=12.0,stddev=1.8,dtype=tf.float32,seed=None,name=None)
print(random)

# %%
#alternative
rand=tf.random.uniform([5,],minval=1,maxval=6,dtype=tf.int32,seed=None,name=None)
print(rand)
